# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12, 9)

# %%
fs = 44100.0
f0 = 2.0

maxharm = min((fs / 2.0) / f0, 200.0)

FSAW = np.arange(1.0, maxharm, 1.0)
SAW = (FSAW, 1.0 / FSAW)

FTRI = np.arange(1.0, maxharm, 2.0)
TRI = (FTRI, 1.0 / (FTRI * FTRI))

FSQUARE = FTRI
SQUARE = (FSQUARE, 1.0 / FSQUARE)

dt = 1.0 / fs
t = np.arange(0.0, 1.0, dt)
f, a = SQUARE

xarr = np.dot(np.eye(f.shape[0]) * a, np.sin(2.0 * np.pi * f0 * f[np.newaxis].T * t[np.newaxis]))
x = np.sum(xarr, axis=0)
plt.plot(x)

# %%
t = np.arange(0.0, 1.0, dt)
f = np.array([218.0, 222.0])
xarr = np.cos(2.0 * np.pi * f[np.newaxis].T * t[np.newaxis])
x = np.sum(xarr, axis=0)
plt.plot(x)

f = np.array([220.0, 2.0])
yarr = np.cos(2.0 * np.pi * f[np.newaxis].T * t[np.newaxis])
y = 2.0 * np.prod(yarr, axis=0)
plt.plot(y)

plt.figure()
Xmag = np.absolute(np.fft.rfft(x))
plt.plot(np.fft.rfftfreq(len(x), dt), X)
plt.xlim([215.0, 225.0])
# Out:
# (215.0, 225.0)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
