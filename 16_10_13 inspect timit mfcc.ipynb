# %%
# %pylab inline
import cPickle as pickle

with open('timit_tiny_utter_mfcc_13.pkl', 'rb') as data_f:
    data = pickle.load(data_f)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_x = [y for x, y in data]
data_y = [x for x, y in data]

data_x_0 = np.array(data_x[0])
xlen, ylen = data_x_0.shape
x, y = np.mgrid[slice(0, xlen, 1),
                slice(0, ylen, 1)]

print data_x_0.shape
print data_y[0]

plt.figure(figsize=(32, 13), dpi=80)
plt.pcolormesh(x, y, data_x_0[:, 1:])
plt.xlim([0, xlen - 1])
plt.ylim([0, ylen - 1])
plt.show()
# Out:
# (312L, 13L)
# ('F', 'CJF0')
