# %%
n = 1000000

import numpy as np
# %pylab inline

x = np.random.rand(n)
y = np.random.rand(n)

def histogram(a):
    z = (1. - a) * x + a * y

    n, bins, patches = plt.hist(z, 201, normed=True)

    plt.title('a={}'.format(a))
    plt.plot(bins)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 2.0])
    plt.figure()

histogram(0.0)
histogram(0.25)
histogram(0.5)
# Out:
# Populating the interactive namespace from numpy and matplotlib
